# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

data = np.load('/home/DAVIDSON/allandolfi/attpc_unpaired_trans/data/Fission/fission_data/Fission_sim.npy')
data2 = np.load('/home/DAVIDSON/allandolfi/attpc_unpaired_trans/data/Fission/fission_data/Fission_exp.npy')

# %%
num_samples = 6
fig = plt.figure(figsize=(18, 10))

for i in range(num_samples):
    sample = data[i]
    x, y, z, amp = sample[:, 0], sample[:, 1], sample[:, 2], sample[:, 3]
    
    ax = fig.add_subplot(2, 3, i + 1, projection='3d')
    sc = ax.scatter(x, y, z, c=charge, cmap='plasma', s=3)
    ax.set_title(f"Sample {i}")
    ax.set_xlabel("x")
    ax.set_ylabel("y")
    ax.set_zlabel("z")

fig.colorbar(sc, ax=fig.get_axes(), shrink=0.5, label='Amplitude')
plt.show()

# %%
num_samples = 6
fig = plt.figure(figsize=(18, 10))

for i in range(num_samples):
    sample = data2[i]
    x, y, z, amp = sample[:, 0], sample[:, 1], sample[:, 2], sample[:, 3]
    
    ax = fig.add_subplot(2, 3, i + 1, projection='3d')
    sc = ax.scatter(x, y, z, c=charge, cmap='plasma', s=3)
    ax.set_title(f"Sample {i}")
    ax.set_xlabel("x")
    ax.set_ylabel("y")
    ax.set_zlabel("z")

fig.colorbar(sc, ax=fig.get_axes(), shrink=0.5, label='Amplitude')
plt.savefig("plot.png")
plt.show()
